# %% [markdown]
# ## 3. A grading assistant
# Teachers in general have a lot of administrations to do and one of those things is grading. Can we create a simple grade assistant to assist a Swedish teacher in grading? This exercise focuses a lot in prompt engineering and afterwards to postprocess the output using Pydantic.
#
# a) Go into this page with examples of students answers to a particular question. Copy some example texts and paste it into files with names like student_text_1.txt, student_text_2.txt.
#
# b) Read these data into python and tell your LLM to grade them.
#
# c) Prompt to get an output of fields proposed_grade, motivation and improvements.
#
# d) Now validate this with pydantic model
#
# e) Output a folder with the following txt files: proposed_grade.txt, motivation.txt and improvements.txt
#
# f) Go into skolverket for Svenska 1 and copy "Betygskriterier" for "Svenska 1". These are the criterias for the different grades. Paste this into a file called criterias.txt.
#
# g) Now repeat b)-e) but with the criterias in your prompt as well. Can you see any differences in the outputs?
#
# h) Can you improve the output quality by providing few shot examples?

# %% [markdown]
# a) Go into this page with examples of students answers to a particular question. Copy some example texts and paste it into files with names like student_text_1.txt, student_text_2.txt.

# %%
from google import genai
from pydantic import BaseModel

# %%
client = genai.Client()

# %%
# list_of_texts = []
with open("student_text_1.txt", "r", encoding = "utf-8") as file:
    student_text = file.read()
    list_of_texts.append(student_text)
list_of_texts[1]
# Out:
# 'Inför allas blickar\nEn av de större andledningarna att man är tal rädd är förmodligen att man är\nrädd för att folket som lyssnar på kommer göra narr av en. När man är ensam\npå en scen eller i klass rummet så är det väldigt jobbigt när det sitter ett flertal\nmänniskor som sitter och tittar på en. Jag känner mig inte så säker när jag står och\ngör en föreläsning eller en presentation. Känslan när man är framför människor\nsom man inte riktigt känner är ganska obehagligt, för man vill inte att dem ska\ntycka illa om en, eller tycka att man är konstig på något vis. Men jag tror att det\ngår att bli av med talrädslan, om man börjar i en mindre grupp och gör sig vann\nmed att prata med människor utan att bli rädd eller känna obehag.\nPeter Letmark skriver i Dagens Nyheter 2012-05-04 att det har att göra med\nevolutionära förklaringar, att man är rädd för ormar eller hundar kan ju vara\nen sak som sitter i ryggmärgen. Det kan bero på att man är rädd för att bli\nutstöt från gruppen. Letmark berättar även att primater organiserar sitt sociala\nliv i hierarkier. Rädslan för att prata i grupp kanske gör att man undviker\ndominanskonflikter. Det Letmark skriver låter ganska rimligt, mina åsikter är\nnästan desamma. Jag tror att det är lättare att prata om något som sitter nära ditt\nhjärta, för att då brinner du för det du pratar om och kan fortsätta väldigt enkelt\nutan att inte veta vad du ska prata om. Om det är något du inte tycker är så\nintressant men måste prata om det av jobb skäl, så blir det nog betydligt svårare.\nMen det blir garanterat lättare om du har bra själv förtroende, dom som har\nlite sämre själv förtroende blir du väldigt osäker på vad du säger och vågar inte\nargumentera om din åsikt.'

# %%
text = {"text1": list_of_texts[0], "text2": list_of_texts[1]}

# %%
grades = []
for text in list_of_texts:
    response = client.models.generate_content(
        model = "gemini-2.5-flash",
        contents = f"""You are a swedish teacher. Rate this text: {text}. Give it a rating between 1-10."""
    )
    print(response.text)
    grades.append(response.text)
# Out:
# Hej! Tack för att du delar med dig av din text. Ämnet är mycket relevant och välvalt, och du tar upp intressanta aspekter kring muntliga presentationer.
#
# **Betyg: 6/10**
#
# **Motivering och konstruktiv feedback:**
#
# Din text har en tydlig struktur och en röd tråd. Du lyckas förmedla ditt budskap och kopplar väl till den refererade artikeln. Du använder även en del bra ord som "talängslan".
#
# Däremot finns det en hel del språkliga fel som drar ner helhetsintrycket och gör texten lite svårläst bitvis. Dessa fel handlar främst om grammatik, ordföljd och ordval.
#
# Här är några specifika punkter du kan arbeta med:
#
# 1.  **Kongruensfel (enkel/plural, utrum/neutrum):**
#     *   "uppleves" ska vara "upplevs".
#     *   "tvingade" (till man) ska vara "tvingad".
#     *   "viktigt egenskap" ska vara "viktig egenskap" (egenskap är en utrum).
#     *   "vanligast rädslan" ska vara "vanligaste rädslan".
#     *   "utstöt" ska vara "utstött".
#
# 2.  **Prepositioner:**
#     *   "van med det" ska vara "van vid det".
#     *   "existerar i människor" ska vara "existerar hos människor".
#     *   "rädslan om att tala" ska vara "rädslan för att tala".
#     *   "med rädslan av att bli utstöt" ska vara "av rädsla för att bli utstött" eller "med rädsla för att bli utstött".
#     *   "med att göra det en vana" ska vara "genom att göra det till en vana".
#
# 3.  **Ordföljd och meningsbyggnad:**
#     *   "komma säkert komma på" - dubbelfel, "kommer säkert att komma på" eller "kommer säkert på".
#     *   "svårare och att tala" ska vara "svårare att tala".
#     *   Den sista meningen "Det viktigaste är att göra det en del av sitt vardagliga liv så att man verkligen måste prestera så är allting inte som en chock.." är väldigt krånglig och behöver omformuleras. Kanske: "Det viktigaste är att göra det till en del av sitt vardagliga liv, så att det inte blir en chock när man väl måste prestera."
#
# 4.  **Ordval/felstavningar:**
#     *   "de" (objekt) ska vara "dem" i "framför dem".
#     *   "fastar" ska vara "fastnar".
#     *   "ta plast" ska vara "ta plats" (ett återkommande fel).
#     *   "utrycka sig" ska vara "uttrycka sig".
#     *   "framför spegel" ska vara "framför spegeln".
#     *   "sen" är informellt, använd "sedan" i en mer formell text.
#     *   "lite åt taget" ska vara "lite i taget".
#
# **Förslag på hur du kan förbättra dig:**
#
# *   **Läs igenom dina texter långsamt:** Försök att läsa varje mening högt för att höra om den låter naturlig.
# *   **Fokusera på prepositionsanvändning:** Detta är ett vanligt område att öva på.
# *   **Repetera böjningsregler:** Se över hur verb, adjektiv och substantiv böjs i svenska (t.ex. pluralformer, bestämd form, utrum/neutrum).
# *   **Be någon annan läsa:** En annan person kan lättare upptäcka fel du själv missar.
#
# Fortsätt att skriva och utveckla dina idéer. Med lite mer fokus på grammatiken kommer dina texter att bli ännu bättre och flyta på ett utmärkt sätt! Bra jobbat med innehållet!
# Hej! Tack för din text. Den är intressant och tar upp ett relevant ämne. Du lyckas förmedla dina tankar väl och blandar personlig reflektion med referenser till en artikel, vilket är bra.
#
# **Betyg: 7/10**
#
# Här är en mer detaljerad genomgång:
#
# **Styrkor:**
#
# *   **Tydlig struktur:** Texten har en bra inledning, utvecklar ämnet med både personliga erfarenheter och en extern källa, och har en sammanhängande röd tråd.
# *   **Välformulerade tankar:** Dina åsikter och argument är lätta att förstå och följa. Du kopplar ihop Letmarks text med dina egna tankar på ett bra sätt.
# *   **God variation i ordförråd:** Du använder ord som "evolutionära förklaringar", "hierarkier", "dominanskonflikter" som visar på ett brett ordförråd.
# *   **Engagerande språk:** Du använder en personlig ton som gör texten levande och lätt att relatera till.
#
# **Att utveckla:**
#
# Det finns en del återkommande grammatiska och stavningsmässiga fel som drar ner helhetsintrycket. Här är de viktigaste punkterna:
#
# 1.  **Sammansatta ord:** Detta är det vanligaste felet. Många ord som är sammansatta i svenskan har du skrivit isär.
#     *   "tal rädd" ska vara **talrädd**
#     *   "klass rummet" ska vara **klassrummet**
#     *   "jobb skäl" ska vara **jobbskäl**
#     *   "själv förtroende" ska vara **självförtroende** (förekommer flera gånger)
#     *   *Tips: I svenskan skrivs sammansatta ord oftast ihop om det första ordet beskriver det andra.*
#
# 2.  **"De" och "Dem":** Du blandar ihop dessa. "De" är subjektsform (vem/vilka?) och "dem" är objektsform (vem/vilka?).
#     *   "vill inte att **dem** ska tycka illa om en" ska vara "vill inte att **de** ska tycka illa om en" (de är subjekt här).
#     *   "**dom** som har lite sämre själv förtroende" ska vara "**de** som har lite sämre självförtroende" (de är subjekt).
#
# 3.  **Stavning:**
#     *   "andledningarna" ska vara **anledningarna**
#     *   "vann med att prata" ska vara **van vid att prata** (adjektivet är "van", prepositionen är "vid").
#     *   "utstöt från gruppen" ska vara **utstött från gruppen** (perfekt particip som adjektiv).
#
# 4.  **Meningsbyggnad och ordval:**
#     *   "folket som lyssnar på" kan förenklas till "de som lyssnar" eller "publiken". "på" är överflödigt.
#     *   "Känslan när man är framför människor som man inte riktigt känner är ganska **obehagligt**" ska vara "**obehaglig**" (känslan är obehaglig, inte obehagligt).
#     *   "utan att **inte** veta vad du ska prata om" är en dubbel negation. Det ska vara "utan att veta" eller "utan att behöva fundera på vad du ska prata om".
#     *   "något som sitter nära ditt hjärta" är förståeligt, men det vanligaste uttrycket är "något som **ligger dig varmt om hjärtat**".
#     *   "argumentera **om** din åsikt" ska oftast vara "argumentera **för** din åsikt".
#
# **Förslag till förbättring:**
#
# *   Läs igenom din text noggrant med fokus på sammansatta ord. Använd gärna en ordlista om du är osäker.
# *   Öva på skillnaden mellan "de" och "dem". Ett knep är att ersätta med engelskans "they" (de) och "them" (dem).
# *   Var uppmärksam på adjektivens böjning (obehaglig/obehagligt).
# *   Läs din text högt för dig själv – det kan hjälpa dig att upptäcka konstiga formuleringar eller dubbla negationer.
#
# Fortsätt skriva och arbeta med dessa punkter, så kommer dina texter att bli ännu starkare! Bra jobbat!

# %%
# c) Prompt to get an output of fields proposed_grade, motivation and improvements.
from typing import Literal
for text in list_of_texts:
    response = client.models.generate_content(
        model = "gemini-2.5-flash",
        contents = f"""You are a swedish teacher. Rate this text: {text}. Give me the following fields:
            proposed_grade: A - F. A being the best grade and F being the worst
            motivation: motivate the grade given to the student
            improvements: what they can improve
            """
    )
    print(response.text)
    grades.append(response.text)
# Out:
# Hej! Tack för din text. Du har tagit dig an ett intressant och relevant ämne, och din text visar att du har en god förståelse för ämnet samt förmågan att argumentera för dina poänger.
#
# **Proposed grade: D**
#
# **Motivation:**
# Din text är välstrukturerad och behandlar ett relevant ämne på ett intressant sätt. Du lyckas föra fram dina tankar tydligt och inkluderar även en extern källa för att stärka dina argument, vilket är mycket bra. Du har ett gott ordförråd som är passande för ämnet.
#
# Däremot finns det en betydande mängd grammatiska fel, felaktiga ordföljder och mindre lämpliga formuleringar som påverkar textens läsbarhet och professionalitet. Dessa fel återkommer frekvent genom hela texten och indikerar att du behöver arbeta mer med grundläggande svensk grammatik och meningsbyggnad.
#
# **Improvements:**
#
# 1.  **Grammatik och meningsbyggnad:** Detta är det viktigaste området att fokusera på.
#     *   **Prepositioner:** Var noga med val av prepositioner (t.ex. "van vid" istället för "van med", "knep för att" istället för "knep på att", "i taget" istället för "åt taget").
#     *   **Adjektivböjning:** Se till att adjektiv böjs korrekt i obestämd/bestämd form och i jämförelse (t.ex. "en bra och *viktig* egenskap," "den *vanligaste* rädslan").
#     *   **Sammansatta ord:** Skriv sammansatta ord som ett ord (t.ex. "överlevnadschanser," "vardagliga liv").
#     *   **"Ju... desto..."-konstruktionen:** Lär dig att använda denna konstruktion korrekt ("Ju mer man pratar... desto mer inser man...").
#     *   **Passiv form:** Använd den vanliga s-passiven ("upplevs" istället för "uppleves").
#     *   **Redundanta ord:** Undvik onödiga "att" efter verb som "börja" (t.ex. "börjar prata" istället för "börjar att prata").
#     *   **Meningsstruktur:** Arbeta med att skapa mer flytande och grammatiskt korrekta meningar. Flera meningar är lite kantiga eller innehåller inkorrekta sammankopplingar (t.ex. "så att man verkligen måste prestera så är allting inte som en chock").
#
# 2.  **Ordval och idiomatiska uttryck:**
#     *   Var noggrann med ordval som "fastnar" (att fastna) istället för "fastar" (att fasta).
#     *   "Ta plats" är rätt uttryck när man menar att våga synas, inte "ta plast."
#     *   "Förr i tiden" är korrekt, inte "för i tiden."
#     *   "Att bli van vid att tala" är en bättre formulering än "att det blir en van att tala".
#
# 3.  **Korrekturläsning:** Läs alltid igenom din text noggrant. Många småfel, som stavfel ("utrycka" istället för "uttrycka") och saknade bestämda former ("spegel" istället för "spegeln"), kan upptäckas vid en noggrann korrekturläsning. Att läsa texten högt kan också hjälpa dig att hitta meningar som låter onaturliga.
#
# Fortsätt att öva på att skriva och var uppmärksam på de grammatiska reglerna. Med mer träning kommer din svenska att bli mycket bättre!
# Hej! Tack för din text. Du tar upp ett intressant och relevant ämne på ett personligt och reflekterande sätt. Här är min bedömning:
#
# **proposed_grade: D**
#
# **motivation:**
# Texten visar att du har en god förståelse för ämnet och att du kan formulera dina tankar på ett sammanhängande sätt. Strukturen är tydlig, du inleder väl, diskuterar olika aspekter av talrädsla och integrerar en extern källa på ett relevant sätt. Dina resonemang är logiska och lätta att följa.
#
# Dock dras betyget ner av ett stort antal språkliga fel. Det handlar främst om sammansatta ord, felaktig användning av pronomen, avsaknad av kongruens (att ord böjs korrekt efter andra ord de syftar på) samt en del mindre stavfel och klumpiga formuleringar. Dessa fel påverkar läsbarheten och flytet i texten, även om de sällan gör texten oförståelig.
#
# **improvements:**
# Här är några konkreta områden du kan förbättra för att lyfta din svenska:
#
# 1.  **Sammansatta ord:** Detta är det mest frekventa felet i din text. I svenskan skrivs många ord ihop som i engelskan är två separata ord. Exempel från din text:
#     *   "tal rädd" ska vara "talrädd"
#     *   "klass rummet" ska vara "klassrummet"
#     *   "jobb skäl" ska vara "jobbskäl"
#     *   "själv förtroende" ska vara "självförtroende"
#     *   *Tips:* Om du kan sätta "och" eller "eller" mellan orden, är det ofta två ord. Om inte, är det troligen ett sammansatt ord (t.ex. "klass och rummet" låter fel, alltså "klassrummet").
#
# 2.  **Pronomen ("de" och "dem"):** Var noga med skillnaden mellan "de" (subjekt – vilka?) och "dem" (objekt – vilka?).
#     *   "vill inte att **dem** ska tycka" ska vara "vill inte att **de** ska tycka" (de är subjekt här)
#     *   "**dom** som har lite sämre" ska vara "**de** som har lite sämre"
#
# 3.  **Kongruens och böjning:** Adjektiv och particip måste stämma överens med det ord de beskriver.
#     *   "Känslan [...] är ganska **obehagligt**" ska vara "Känslan [...] är ganska **obehaglig**" (eftersom "känslan" är en *en*-ord).
#     *   "bli **utstöt** från gruppen" ska vara "bli **utstött** från gruppen" (participet ska böjas)
#
# 4.  **Stavning:** En del mindre stavfel som kan åtgärdas med noggrann korrekturläsning.
#     *   "andledningarna" ska vara "anledningarna"
#     *   "gör sig **vann** med att prata" ska vara "gör sig **van** vid att prata" (idiom)
#
# 5.  **Redundans och klarspråk:** Försök att undvika dubbla negationer och onödiga upprepningar.
#     *   "utan att **inte veta** vad du ska prata om" ska vara "utan att behöva fundera över vad du ska prata om" eller "utan att tveka"
#     *   "ett flertal människor som **sitter och** tittar på en" kan förenklas till "ett flertal människor som tittar på en"
#
# 6.  **Konsekvent perspektiv ("man" vs "du"):** Du börjar texten med "man" men byter till "du" i slutet. Försök att vara konsekvent i valet av pronomen genom hela texten för att bibehålla en enhetlig ton.
#     *   "**blir du** väldigt osäker på vad du säger" bör vara "**blir man** väldigt osäker på vad man säger"
#
# 7.  **Prepositioner:** Var uppmärksam på korrekta prepositioner i fasta uttryck.
#     *   "argumentera **om** din åsikt" ska vara "argumentera **för** sin åsikt"
#
# Fortsätt skriva och arbeta med dessa punkter, så kommer din svenska att förbättras markant!

# %%
# d) Now validate this with pydantic model
