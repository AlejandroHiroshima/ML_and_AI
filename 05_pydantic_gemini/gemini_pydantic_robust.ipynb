# %% [markdown]
# # Structure gemini outputs in a robust way

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
    structure it in json format
    """
)

print(response.text)
# Out:
# ```json
# [
#   {
#     "name": "Pho Bo",
#     "origin": "Vietnam",
#     "description": "Aromatic, deeply comforting Vietnamese beef noodle soup with a crystal-clear broth simmered for hours, fragrant with star anise, cinnamon, and ginger. Loaded with silky rice noodles, tender slices of rare beef, and a vibrant medley of fresh herbs like basil, cilantro, and mint. Each spoonful is a warm embrace of savory goodness, perfect for a chilly day or any time you crave profound flavor.",
#     "ingredients": [
#       "Beef bones (knuckles, oxtail)",
#       "Onion",
#       "Ginger",
#       "Star anise",
#       "Cinnamon sticks",
#       "Black cardamom",
#       "Cloves",
#       "Fish sauce",
#       "Sugar",
#       "Salt",
#       "Dried flat rice noodles (Banh Pho)",
#       "Thinly sliced beef (sirloin, eye of round, brisket)",
#       "Fresh bean sprouts",
#       "Limes",
#       "Jalapeño/serrano peppers",
#       "Thai basil",
#       "Cilantro",
#       "Mint",
#       "Hoisin sauce (for serving)",
#       "Sriracha (for serving)"
#     ]
#   },
#   {
#     "name": "Tom Yum Goong",
#     "origin": "Thailand",
#     "description": "A vibrant and exhilarating Thai hot and sour soup, bursting with an irresistible balance of spicy, sour, salty, and sweet flavors. Fragrant with lemongrass, galangal, kaffir lime leaves, and fresh chilies, this iconic soup features plump, juicy shrimp and earthy mushrooms in a clear or creamy broth. It's an explosion of exotic tastes that will awaken your palate!",
#     "ingredients": [
#       "Shrimp (fresh, head-on preferred)",
#       "Lemongrass stalks",
#       "Galangal (or ginger)",
#       "Kaffir lime leaves",
#       "Bird's eye chilies",
#       "Fish sauce",
#       "Lime juice",
#       "Mushrooms (straw or oyster)",
#       "Cherry tomatoes",
#       "Cilantro",
#       "Tom Yum paste (optional, for creamy version)",
#       "Coconut milk or evaporated milk (optional, for creamy version)"
#     ]
#   },
#   {
#     "name": "Tonkotsu Ramen",
#     "origin": "Japan",
#     "description": "Indulge in the ultimate comfort with Tonkotsu Ramen, a Japanese masterpiece featuring a milky-white, incredibly rich and savory pork bone broth, simmered for hours until velvety smooth. Paired with perfectly chewy ramen noodles, tender slices of chashu (braised pork belly), a perfectly soft-boiled ajitama egg, crisp nori, and fresh scallions. It’s a soulful, deeply satisfying bowl of umami that warms you from the inside out.",
#     "ingredients": [
#       "Pork bones (trotters, neck, back)",
#       "Onion",
#       "Garlic",
#       "Ginger",
#       "Leek",
#       "Fresh ramen noodles",
#       "Chashu (braised pork belly)",
#       "Ajitama (marinated soft-boiled egg)",
#       "Nori (seaweed sheets)",
#       "Scallions",
#       "Bean sprouts",
#       "Menma (fermented bamboo shoots)",
#       "Soy sauce",
#       "Mirin",
#       "Sake"
#     ]
#   },
#   {
#     "name": "Laksa (Curry Laksa)",
#     "origin": "Malaysia / Singapore",
#     "description": "A deeply aromatic and incredibly rich Malaysian/Singaporean curry noodle soup that's a true flavor bomb! A creamy, spicy coconut milk broth infused with a complex blend of spices, galangal, turmeric, and lemongrass, enveloping thick rice vermicelli and sometimes egg noodles. Loaded with tender chicken, succulent shrimp, fish cakes, and tofu puffs. Each spoonful is a luxurious journey into Southeast Asian culinary bliss.",
#     "ingredients": [
#       "Coconut milk",
#       "Laksa paste (dried chilies, shallots, garlic, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste)",
#       "Chicken broth/stock",
#       "Thick rice vermicelli noodles",
#       "Yellow egg noodles (optional)",
#       "Chicken (shredded)",
#       "Shrimp",
#       "Fish cakes",
#       "Tofu puffs",
#       "Bean sprouts",
#       "Fresh cilantro",
#       "Lime wedges",
#       "Sambal (chili paste, for serving)"
#     ]
#   },
#   {
#     "name": "Hot and Sour Soup",
#     "origin": "China",
#     "description": "A classic Chinese soup that perfectly balances the zesty tang of vinegar with a fiery kick of white pepper and chili, all in a savory, silky broth. Loaded with strips of pork, bamboo shoots, wood ear mushrooms, tofu, and wisps of egg, creating a delightful textural contrast. It's a comforting, warming, and invigorating bowl that tantalizes the taste buds with every spoonful.",
#     "ingredients": [
#       "Chicken or vegetable broth",
#       "Pork (shredded)",
#       "Tofu (firm, shredded)",
#       "Bamboo shoots (shredded)",
#       "Wood ear mushrooms (shredded)",
#       "Shiitake mushrooms (shredded)",
#       "Rice vinegar",
#       "Soy sauce",
#       "White pepper",
#       "Chili oil (optional)",
#       "Sesame oil",
#       "Cornstarch slurry",
#       "Egg (whisked)",
#       "Green onions (for garnish)"
#     ]
#   }
# ]
# ```

# %%
print(response.text.strip("```json"))
# Out:
# [
#   {
#     "name": "Pho Bo",
#     "origin": "Vietnam",
#     "description": "Aromatic, deeply comforting Vietnamese beef noodle soup with a crystal-clear broth simmered for hours, fragrant with star anise, cinnamon, and ginger. Loaded with silky rice noodles, tender slices of rare beef, and a vibrant medley of fresh herbs like basil, cilantro, and mint. Each spoonful is a warm embrace of savory goodness, perfect for a chilly day or any time you crave profound flavor.",
#     "ingredients": [
#       "Beef bones (knuckles, oxtail)",
#       "Onion",
#       "Ginger",
#       "Star anise",
#       "Cinnamon sticks",
#       "Black cardamom",
#       "Cloves",
#       "Fish sauce",
#       "Sugar",
#       "Salt",
#       "Dried flat rice noodles (Banh Pho)",
#       "Thinly sliced beef (sirloin, eye of round, brisket)",
#       "Fresh bean sprouts",
#       "Limes",
#       "Jalapeño/serrano peppers",
#       "Thai basil",
#       "Cilantro",
#       "Mint",
#       "Hoisin sauce (for serving)",
#       "Sriracha (for serving)"
#     ]
#   },
#   {
#     "name": "Tom Yum Goong",
#     "origin": "Thailand",
#     "description": "A vibrant and exhilarating Thai hot and sour soup, bursting with an irresistible balance of spicy, sour, salty, and sweet flavors. Fragrant with lemongrass, galangal, kaffir lime leaves, and fresh chilies, this iconic soup features plump, juicy shrimp and earthy mushrooms in a clear or creamy broth. It's an explosion of exotic tastes that will awaken your palate!",
#     "ingredients": [
#       "Shrimp (fresh, head-on preferred)",
#       "Lemongrass stalks",
#       "Galangal (or ginger)",
#       "Kaffir lime leaves",
#       "Bird's eye chilies",
#       "Fish sauce",
#       "Lime juice",
#       "Mushrooms (straw or oyster)",
#       "Cherry tomatoes",
#       "Cilantro",
#       "Tom Yum paste (optional, for creamy version)",
#       "Coconut milk or evaporated milk (optional, for creamy version)"
#     ]
#   },
#   {
#     "name": "Tonkotsu Ramen",
#     "origin": "Japan",
#     "description": "Indulge in the ultimate comfort with Tonkotsu Ramen, a Japanese masterpiece featuring a milky-white, incredibly rich and savory pork bone broth, simmered for hours until velvety smooth. Paired with perfectly chewy ramen noodles, tender slices of chashu (braised pork belly), a perfectly soft-boiled ajitama egg, crisp nori, and fresh scallions. It’s a soulful, deeply satisfying bowl of umami that warms you from the inside out.",
#     "ingredients": [
#       "Pork bones (trotters, neck, back)",
#       "Onion",
#       "Garlic",
#       "Ginger",
#       "Leek",
#       "Fresh ramen noodles",
#       "Chashu (braised pork belly)",
#       "Ajitama (marinated soft-boiled egg)",
#       "Nori (seaweed sheets)",
#       "Scallions",
#       "Bean sprouts",
#       "Menma (fermented bamboo shoots)",
#       "Soy sauce",
#       "Mirin",
#       "Sake"
#     ]
#   },
#   {
#     "name": "Laksa (Curry Laksa)",
#     "origin": "Malaysia / Singapore",
#     "description": "A deeply aromatic and incredibly rich Malaysian/Singaporean curry noodle soup that's a true flavor bomb! A creamy, spicy coconut milk broth infused with a complex blend of spices, galangal, turmeric, and lemongrass, enveloping thick rice vermicelli and sometimes egg noodles. Loaded with tender chicken, succulent shrimp, fish cakes, and tofu puffs. Each spoonful is a luxurious journey into Southeast Asian culinary bliss.",
#     "ingredients": [
#       "Coconut milk",
#       "Laksa paste (dried chilies, shallots, garlic, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste)",
#       "Chicken broth/stock",
#       "Thick rice vermicelli noodles",
#       "Yellow egg noodles (optional)",
#       "Chicken (shredded)",
#       "Shrimp",
#       "Fish cakes",
#       "Tofu puffs",
#       "Bean sprouts",
#       "Fresh cilantro",
#       "Lime wedges",
#       "Sambal (chili paste, for serving)"
#     ]
#   },
#   {
#     "name": "Hot and Sour Soup",
#     "origin": "China",
#     "description": "A classic Chinese soup that perfectly balances the zesty tang of vinegar with a fiery kick of white pepper and chili, all in a savory, silky broth. Loaded with strips of pork, bamboo shoots, wood ear mushrooms, tofu, and wisps of egg, creating a delightful textural contrast. It's a comforting, warming, and invigorating bowl that tantalizes the taste buds with every spoonful.",
#     "ingredients": [
#       "Chicken or vegetable broth",
#       "Pork (shredded)",
#       "Tofu (firm, shredded)",
#       "Bamboo shoots (shredded)",
#       "Wood ear mushrooms (shredded)",
#       "Shiitake mushrooms (shredded)",
#       "Rice vinegar",
#       "Soy sauce",
#       "White pepper",
#       "Chili oil (optional)",
#       "Sesame oil",
#       "Cornstarch slurry",
#       "Egg (whisked)",
#       "Green onions (for garnish)"
#     ]
#   }
# ]

# %%
from pydantic import BaseModel
from google import genai

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
    structure it in json format
    """,
    config={"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [
#   {
#     "recipe_name": "Miso Soup",
#     "description": "A traditional Japanese soup, Miso Soup is a light and savory dish made from dashi stock and miso paste, often containing tofu, seaweed, and green onions. It's a comforting and healthy staple of Japanese cuisine.",
#     "ingredients": [
#       "4 cups dashi stock",
#       "4 tablespoons miso paste",
#       "1/2 block silken tofu, diced",
#       "2 tablespoons dried wakame seaweed, rehydrated",
#       "2 green onions, sliced"
#     ]
#   },
#   {
#     "recipe_name": "Tom Yum Goong (Spicy Shrimp Soup)",
#     "description": "Tom Yum Goong is a vibrant and aromatic Thai hot and sour soup, bursting with flavors of lemongrass, galangal, kaffir lime leaves, and a spicy kick from chilies, typically made with succulent shrimp and mushrooms.",
#     "ingredients": [
#       "1 lb large shrimp, peeled and deveined",
#       "4 cups chicken or vegetable broth",
#       "2 stalks lemongrass, bruised and sliced",
#       "5 slices galangal",
#       "6 kaffir lime leaves, torn",
#       "1 cup straw mushrooms or oyster mushrooms",
#       "3-4 bird's eye chilies, crushed (or 1-2 tbsp chili paste)",
#       "3 tablespoons fish sauce",
#       "4 tablespoons lime juice",
#       "Cilantro for garnish"
#     ]
#   },
#   {
#     "recipe_name": "Vietnamese Pho Bo (Beef Noodle Soup)",
#     "description": "Pho Bo is Vietnam's iconic noodle soup, renowned for its deeply flavorful and aromatic broth, tender slices of beef, and slippery rice noodles, traditionally served with a plate of fresh herbs and bean sprouts.",
#     "ingredients": [
#       "2 lbs beef bones (knuckle and marrow)",
#       "1 lb beef flank or brisket",
#       "1 large onion, halved and charred",
#       "4-inch piece ginger, halved and charred",
#       "4-5 star anise pods",
#       "2 cinnamon sticks",
#       "6-8 whole cloves",
#       "2 tablespoons fish sauce",
#       "1 tablespoon sugar",
#       "Salt to taste",
#       "1 lb flat rice noodles (banh pho)",
#       "Fresh herbs (basil, cilantro, mint)",
#       "Bean sprouts",
#       "Lime wedges",
#       "Sliced jalapeños (optional)"
#     ]
#   }
# ]
