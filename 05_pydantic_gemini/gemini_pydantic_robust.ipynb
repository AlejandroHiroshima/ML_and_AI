# %% [markdown]
# # Structure gemini outputs in a robust way

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
    structure it in json format
    """
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[14], line 5
#       1 from google import genai
#       3 client = genai.Client()
# ----> 5 response = client.models.generate_content(
#       6     model= "gemini-2.5-flash",
#       7     contents = """List a few asian soups recipes, a yummy description and list the ingredients
#       8     structure it in json format
#       9     """
#      10 )
#      12 print(response.text)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\models.py:4000, in Models._generate_content(self, model, contents, config)
#    3997 request_dict = _common.convert_to_dict(request_dict)
#    3998 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4000 response = self._api_client.request(
#    4001     'post', path, request_dict, http_options
#    4002 )
#    4004 if config is not None and getattr(
#    4005     config, 'should_return_http_response', None
#    4006 ):
#    4007   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1330, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1320 def request(
#    1321     self,
#    1322     http_method: str,
#    (...)   1325     http_options: Optional[HttpOptionsOrDict] = None,
#    1326 ) -> SdkHttpResponse:
#    1327   http_request = self._build_request(
#    1328       http_method, path, request_dict, http_options
#    1329   )
# -> 1330   response = self._request(http_request, http_options, stream=False)
#    1331   response_body = (
#    1332       response.response_stream[0] if response.response_stream else ''
#    1333   )
#    1334   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1166, in BaseApiClient._request(self, http_request, http_options, stream)
#    1163     retry = tenacity.Retrying(**retry_kwargs)
#    1164     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1166 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1143, in BaseApiClient._request_once(self, http_request, stream)
#    1135 else:
#    1136   response = self._httpx_client.request(
#    1137       method=http_request.method,
#    1138       url=http_request.url,
#    (...)   1141       timeout=http_request.timeout,
#    1142   )
# -> 1143   errors.APIError.raise_for_response(response)
#    1144   return HttpResponse(
#    1145       response.headers, response if stream else [response.text]
#    1146   )
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\errors.py:106, in APIError.raise_for_response(cls, response)
#     103 else:
#     104   response_json = response.body_segments[0].get('error', {})
# --> 106 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\errors.py:131, in APIError.raise_error(cls, status_code, response_json, response)
#     117 """Raises an appropriate APIError subclass based on the status code.
#     118
#     119 Args:
#    (...)    128   APIError: For other error status codes.
#     129 """
#     130 if 400 <= status_code < 500:
# --> 131   raise ClientError(status_code, response_json, response)
#     132 elif 500 <= status_code < 600:
#     133   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key expired. Please renew the API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key expired. Please renew the API key.'}]}}

# %%
print(response.text.strip("```json"))
# Out:
# [
#   {
#     "name": "Tom Yum Goong (Spicy Thai Shrimp Soup)",
#     "description": "A vibrant and fiery Thai masterpiece, Tom Yum Goong is an aromatic hot and sour soup bursting with plump shrimp, exotic herbs, and a perfect balance of spicy, sour, and savory notes. Each spoonful is a tantalizing dance of flavors that awakens the senses.",
#     "ingredients": [
#       "Shrimp (peeled, deveined)",
#       "Mushrooms (straw or oyster)",
#       "Lemongrass (sliced)",
#       "Galangal (sliced)",
#       "Kaffir lime leaves",
#       "Fish sauce",
#       "Lime juice",
#       "Chili paste (Tom Yum paste)",
#       "Fresh bird's eye chilies (crushed)",
#       "Cilantro (for garnish)",
#       "Chicken or vegetable broth"
#     ]
#   },
#   {
#     "name": "Shoyu Ramen (Japanese Soy Sauce Ramen)",
#     "description": "A comforting bowl of Japanese culinary art, Shoyu Ramen features springy ramen noodles luxuriating in a clear, deeply savory soy-sauce-based broth. Crowned with tender chashu pork, a perfectly soft-boiled egg, crisp nori, and fresh scallions, it's an umami-rich experience that warms the soul.",
#     "ingredients": [
#       "Ramen noodles",
#       "Chicken or pork broth",
#       "Soy sauce (shoyu)",
#       "Mirin",
#       "Sake",
#       "Chashu pork slices",
#       "Soft-boiled egg (ajitsuke tamago)",
#       "Nori (seaweed)",
#       "Scallions (chopped)",
#       "Sesame oil",
#       "Ginger & garlic (for broth)"
#     ]
#   },
#   {
#     "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "description": "An iconic Vietnamese delight, Pho Bo is a fragrant and deeply satisfying beef noodle soup. Its star is an incredibly aromatic broth, simmered for hours with warming spices, served with slippery rice noodles, thinly sliced tender beef, and a fresh medley of herbs and sprouts that create a harmonious and incredibly flavorful symphony.",
#     "ingredients": [
#       "Beef bones (for broth)",
#       "Beef brisket or flank steak (thinly sliced)",
#       "Rice noodles (banh pho)",
#       "Star anise",
#       "Cinnamon sticks",
#       "Cloves",
#       "Black cardamom pods",
#       "Ginger",
#       "Onion",
#       "Fish sauce",
#       "Lime wedges",
#       "Bean sprouts",
#       "Fresh basil",
#       "Cilantro",
#       "Jalapeño or Sriracha (optional)"
#     ]
#   },
#   {
#     "name": "Laksa (Malaysian/Singaporean Coconut Curry Noodle Soup)",
#     "description": "A rich and vibrant Southeast Asian sensation, Laksa is a creamy, spicy, and wonderfully aromatic coconut curry noodle soup. Boasting a complex blend of flavors from a fragrant spice paste, it's loaded with rice vermicelli, succulent shrimp, fish cakes, and tofu puffs, offering a hearty and intensely satisfying culinary adventure.",
#     "ingredients": [
#       "Coconut milk",
#       "Chicken or seafood broth",
#       "Laksa paste (chili, shallots, galangal, lemongrass, turmeric, candlenuts)",
#       "Rice vermicelli noodles",
#       "Shrimp (peeled, deveined)",
#       "Fish cakes (sliced)",
#       "Tofu puffs",
#       "Bean sprouts",
#       "Hard-boiled egg (halved)",
#       "Lime wedges",
#       "Fresh cilantro or laksa leaves (Vietnamese coriander)"
#     ]
#   }
# ]

# %%
from pydantic import BaseModel
from google import genai

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model= "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
    structure it in json format
    """,
    config={"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[12], line 11
#       7     ingredients: list[str]
#       9 client = genai.Client()
# ---> 11 response = client.models.generate_content(
#      12     model= "gemini-2.5-flash",
#      13     contents = """List a few asian soups recipes, a yummy description and list the ingredients
#      14     structure it in json format
#      15     """,
#      16     config={"response_mime_type": "application/json", "response_schema": list[Recipe]}
#      17 )
#      19 print(response.text)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\models.py:4000, in Models._generate_content(self, model, contents, config)
#    3997 request_dict = _common.convert_to_dict(request_dict)
#    3998 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4000 response = self._api_client.request(
#    4001     'post', path, request_dict, http_options
#    4002 )
#    4004 if config is not None and getattr(
#    4005     config, 'should_return_http_response', None
#    4006 ):
#    4007   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1330, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1320 def request(
#    1321     self,
#    1322     http_method: str,
#    (...)   1325     http_options: Optional[HttpOptionsOrDict] = None,
#    1326 ) -> SdkHttpResponse:
#    1327   http_request = self._build_request(
#    1328       http_method, path, request_dict, http_options
#    1329   )
# -> 1330   response = self._request(http_request, http_options, stream=False)
#    1331   response_body = (
#    1332       response.response_stream[0] if response.response_stream else ''
#    1333   )
#    1334   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1166, in BaseApiClient._request(self, http_request, http_options, stream)
#    1163     retry = tenacity.Retrying(**retry_kwargs)
#    1164     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1166 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\_api_client.py:1143, in BaseApiClient._request_once(self, http_request, stream)
#    1135 else:
#    1136   response = self._httpx_client.request(
#    1137       method=http_request.method,
#    1138       url=http_request.url,
#    (...)   1141       timeout=http_request.timeout,
#    1142   )
# -> 1143   errors.APIError.raise_for_response(response)
#    1144   return HttpResponse(
#    1145       response.headers, response if stream else [response.text]
#    1146   )
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\errors.py:106, in APIError.raise_for_response(cls, response)
#     103 else:
#     104   response_json = response.body_segments[0].get('error', {})
# --> 106 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\alexa\Documents\ML_and_AI\.venv\Lib\site-packages\google\genai\errors.py:131, in APIError.raise_error(cls, status_code, response_json, response)
#     117 """Raises an appropriate APIError subclass based on the status code.
#     118
#     119 Args:
#    (...)    128   APIError: For other error status codes.
#     129 """
#     130 if 400 <= status_code < 500:
# --> 131   raise ClientError(status_code, response_json, response)
#     132 elif 500 <= status_code < 600:
#     133   raise ServerError(status_code, response_json, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}
